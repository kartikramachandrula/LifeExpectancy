# %% [markdown]
# ## Basic MLR

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import pandas as pd

cleaned = pd.read_csv('datasets/cleaned_life_expectancy_data.csv')
X = cleaned.drop(columns=['Life Expectancy'])
y = cleaned['Life Expectancy']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

mlr = LinearRegression()
mlr.fit(X_train, y_train)
y_pred_mlr = mlr.predict(X_test)
# Out:
# Mean Squared Error (MLR): 13.513817159881349

# %%
# Calculate the mean squared error
mse_mlr = mean_squared_error(y_test, y_pred_mlr)
print(f'Mean Squared Error (MLR): {mse_mlr}')

import matplotlib.pyplot as plt

# Plot the MSE for MLR
plt.figure(figsize=(10, 6))
plt.plot(range(len(y_test)), y_test, label='Actual')
plt.plot(range(len(y_pred_mlr)), y_pred_mlr, label='Predicted (MLR)')
plt.xlabel('Sample Index')
plt.ylabel('Life Expectancy')
plt.title('Actual vs Predicted Life Expectancy (MLR)')
plt.legend()
plt.show()
# Take a subsection of sample indexes around 50
sample_indexes = range(50, 100)
y_test_sample = y_test.iloc[sample_indexes]
y_pred_mlr_sample = y_pred_mlr[sample_indexes]

# Plot the MSE for MLR for the sample
plt.figure(figsize=(10, 6))
plt.plot(sample_indexes, y_test_sample, label='Actual')
plt.plot(sample_indexes, y_pred_mlr_sample, label='Predicted (MLR)')
plt.xlabel('Sample Index')
plt.ylabel('Life Expectancy')
plt.title('Actual vs Predicted Life Expectancy (MLR) - Sample')
plt.legend()
plt.show()
# Out:
# Mean Squared Error (MLR): 13.513817159881349

# %% [markdown]
# ## ElasticNet Regression|

# %%
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import pandas as pd


# Initialize the ElasticNet model
elastic_net = ElasticNet()

# Fit the model to the training data
elastic_net.fit(X_train, y_train)

# Predict on the test data
y_pred = elastic_net.predict(X_test)

# Calculate the mean squared error
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       3 from sklearn.metrics import mean_squared_error
#       5 # Assuming cleaned_life_expectancy_data is a pandas DataFrame
#       6 # and the target variable is named 'LifeExpectancy'
#       7
#       8 # Define features and target
# ----> 9 X = cleaned_life_expectancy_data.drop(columns=['LifeExpectancy'])
#      10 y = cleaned_life_expectancy_data['LifeExpectancy']
#      12 # Split the data into training and testing sets
#
# NameError: name 'cleaned_life_expectancy_data' is not defined
